# %% [markdown]
# $$\textbf{ Задание 1 (IO.NET) }$$
#
# **Часть 1:**
# Для начала мне пришлось получать Web3 Score - к счастью, с этим не возникло особых проблем, т.к. у меня имелся Galxe паспорт, который дает возможность бесплатно на 2 месяца оформить Web3 Score.
# После я выполнил все социальные задания, которые были мне под силу (твиттер, медиум, ютуб, дискорд)
# К сожалению, некоторые задания дискорда связаны с временными промежутками (отправлять сообщения в общем чате в течение 10-50 дней)  из-за чего выполнить их мне не представлялось возможным

# %% [markdown]
# ![IMAGE%202024-04-04%2014:12:02.jpg](attachment:IMAGE%202024-04-04%2014:12:02.jpg)

# %% [markdown]
# **Часть 2:**
# Выполнил все задания, связанные с твиттером, никаких трудностей не было

# %% [markdown]
# ![IMAGE%202024-04-04%2014:19:57.jpg](attachment:IMAGE%202024-04-04%2014:19:57.jpg)

# %% [markdown]
# **Часть 3:**
# Тоже никаких проблем не возникло — обычные ежедневные задания, связанные с переходом на важные для проекта материалы

# %% [markdown]
# ![IMAGE%202024-04-04%2014:20:17.jpg](attachment:IMAGE%202024-04-04%2014:20:17.jpg)

# %% [markdown]
# **Часть 4:**
# Первое, с чего начал — это изучать как получить данные роли и возможно ли это вообще, т.к. бывают случаи, особенно с ролями OG, которые выдавали только самым ранним пользователям, из-за чего в дальнейшем их получение было невозможным.
# Данные роли доступны, но именно сейчас, мне, как человеку, который впервые зашел на их сервер, предоставлялась лишь одна роль — Airdrop Tier 1, где единственным условием после прохождение каптчи было указание своего Solana кошелька. Для остальных тиров нужно было как минимум присутствовать на AMA сессиях проекта, а как максимум — создавать контент и помогать модераторам.

# %% [markdown]
# ![IMAGE%202024-04-04%2014:20:44.jpg](attachment:IMAGE%202024-04-04%2014:20:44.jpg)

# %% [markdown]
# **Часть 5:**
# Нужно было просто указать свой Solana кошелек, с чем я успешно справился

# %% [markdown]
# ![IMAGE%202024-04-04%2014:21:23.jpg](attachment:IMAGE%202024-04-04%2014:21:23.jpg)

# %% [markdown]
# $$\textbf{ Задание 2 (XION)  }$$
#
# **Часть 1:**
# Первым решил выполнить приветственное задание, где нужно было подключить твиттер и дискорд

# %% [markdown]
# ![IMAGE%202024-04-04%2014:22:11.jpg](attachment:IMAGE%202024-04-04%2014:22:11.jpg)

# %% [markdown]
# **Часть 2:**
# Следом выполнил задание, связанное с рефералами, где 2 моих "друга" (другие аккаунты) должны были также выполнить приветственное задание

# %% [markdown]
# ![IMAGE%202024-04-04%2014:22:50.jpg](attachment:IMAGE%202024-04-04%2014:22:50.jpg)

# %% [markdown]
# **Часть 3:**
# Раз уж я выполнил прошлое задание, где мне требовались рефералы, то решил закончить и этот квест. Единственное, с чем неприятным я столкнулся - около часа не засчитывало выполнение задания, но т.к. это тестнет, то понимаю, что подобное в порядке вещей

# %% [markdown]
# ![IMAGE%202024-04-04%2014:23:13.jpg](attachment:IMAGE%202024-04-04%2014:23:13.jpg)

# %% [markdown]
# **Часть 4:**
# Данное задание я скипнул, т.к. не являюсь билдером проекта

# %% [markdown]
# ![IMAGE%202024-04-04%2014:23:29.jpg](attachment:IMAGE%202024-04-04%2014:23:29.jpg)

# %% [markdown]
# **Часть 5:**
# Этот квест также пришлось скипать, потому что на его выполнение потребуется минимум неделя, где мне ещё должно повезти, дабы я выиграл WL на минт этого бейджа

# %% [markdown]
# ![IMAGE%202024-04-04%2014:24:22.jpg](attachment:IMAGE%202024-04-04%2014:24:22.jpg)

# %% [markdown]
# **Часть 6:**
# Выполнил я и задание со стейкингом/делегированием. Единственной проблемой, с которой мне пришлось столкнуться — это то, что если раньше его можно было выполнить за 1 получение тестовых токенов, то теперь кол-во получаемых монет уменьшено в 2 раза, из-за чего этого не хватало для завершения квеста. Пришлось оставить его на полпути и доделать уже на следующий день (Тестовые токены можно запрашивать раз в сутки)

# %% [markdown]
# ![IMAGE%202024-04-04%2014:24:44.jpg](attachment:IMAGE%202024-04-04%2014:24:44.jpg)

# %% [markdown]
# **Часть 7:**
# К сожалению, данный квест мне так и не засчитали как выполненный, из-за чего сминтить бейдж я не смог. Не совсем понимаю почему так произошло, ведь я делал четко то, что указано на сайте в описании задания - получал тестовые токены, открывал пул, брал токены взаймы, отдавал их обратно. Даже поискал гайды от инфлов, где в комментариях к их постам я узнал, что данный квест могут не засчитывать пару суток, возможно, что именно с подобной проблемой я и столкнулся

# %% [markdown]
# ![IMAGE%202024-04-04%2014:25:04.jpg](attachment:IMAGE%202024-04-04%2014:25:04.jpg)

# %% [markdown]
# **Часть 8:**
# Первый бейдж забирается путем подписки на твиттер и входа в дискорд, а у второго имеется похожая проблема, как с квестами от IO.NET, так и с квестом про стейкинг/делегирование уже от самого XION - в одном из вариантов действий, которые я опишу ниже, потребуется несколько дней на выполнение.
#
# Для выполнения существует 2 разных способа действия:
#
# 1. Копить по 3 бакса каждый день, которые мы получаем с крана
#
# 2. Попробовать приумножить 3 бакса, которые нам выдал кран и превратить их в 25 баксов (Именно такая сумма нужна, чтобы можно было получить бейдж) т.к. у меня ограниченный дедлайн, я решил воспользоваться способом номер 2 и проиграл тестовые доллары, в связи с чем выполнить квест я не смог

# %% [markdown]
# ![IMAGE%202024-04-04%2014:28:36.jpg](attachment:IMAGE%202024-04-04%2014:28:36.jpg)

# %% [markdown]
# **Часть 9:**
# Дополнительно во вкладке LeaderBoard я забрал бейдж, который выдается от кол-ва набранного с других бейджей опыта

# %% [markdown]
# ![IMAGE%202024-04-04%2014:30:05.jpg](attachment:IMAGE%202024-04-04%2014:30:05.jpg)
